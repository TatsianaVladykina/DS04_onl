# %% [markdown]
# #HW (22.12.2022)

# %% [markdown]
# 1. В списке чисел проверить, все ли элементы являются уникальными, т. е. каждое число встречается только один раз.
# [9, 47, 78, 54, 92, 63, 59, 89, 96, 47, 95, 29, 99, 20, 4, 28, 10, 9, 45, 40, 67, 3, 62, 62, 14, 39, 46, 9, 63, 87, 31, 15, 67, 17, 81, 1, 91, 97, 53, 9, 66, 15, 34, 72, 68, 85, 20, 84, 36, 49]

# %%
list1 = [9, 47, 78, 54, 92, 63, 59, 89, 96, 47, 95, 29, 99, 20, 4, 28, 10, 9, 45, 40, 67, 3, 62, 62, 14, 39, 46, 9, 63, 87, 31, 15, 67, 17, 81, 1, 91, 97, 53, 9, 66, 15, 34, 72, 68, 85, 20, 84, 36, 49]
set1 = set(list1) # преобразование списка во множество для удаления дубликатов
print(len(list1) == len(set1))
# Out:
# False

# %% [markdown]
# 2. Найдите три ключа с самыми высокими значениями в словаре my_dict = {'a':500, 'b':5874, 'c': 560,'d':400, 'e':5874, 'f': 20}.

# %%
my_dict = {
    'a': 500, 
    'b': 5874, 
    'c': 560,
    'd': 400, 
    'e': 5874, 
    'f': 20
}
max_keys = sorted(my_dict, key = my_dict.get, reverse = True)[:3] # key ожидает функцию, с помощью которой должно быть выполнено сравнение; флагом reverse задаем сортировку по убыванию
print(max_keys)
# Out:
# ['b', 'e', 'c']

# %% [markdown]
# 3. Напишите проверку на то, является ли строка палиндромом. Палиндром — это слово или фраза, которые одинаково читаются слева направо и справа налево.

# %%
str1 = input("Enter a word:")
str2 = str1[::-1]
print(str1 == str2)
# Out:
# Enter a word:dad
# True

# %% [markdown]
# 4. Напишите программу, которая принимает два списка и выводит все элементы первого, которых нет во втором.

# %%
list1 = [1, 2, 3, 4, 5, 6]
list2 = [3, 5, 7, 8 ,9]
for i in list1:
  if i not in list2:
    print(i, end=' ')
# Out:
# 1 2 4 6

# %% [markdown]
# 5. Определить существование треугольника по трем сторонам
# У треугольника сумма любых двух сторон должна быть больше третьей. Иначе две стороны просто "лягут" на третью и треугольника не получится. Пользователь вводит длины трех сторон. Программа должна определять, может ли существовать треугольник при таких длинах.

# %%
a = input("Enter a:")
b = input("Enter b:")
c = input("Enter c:")
if a + b > c and a + c > b and b + c > a:
  print("Triangle exists")
else:
  print("Triangle doesn't exist")
# Out:
# Enter a:5
# Enter b:4
# Enter c:9
# Triangle doesn't exist

# %% [markdown]
# 6. Написать функцию программу, принимающую 1 аргумент — число от 0 до 1000, и возвращающую True, если оно простое, и False - иначе

# %%
a = int(input("Enter a:"))
result = True
if a in range(2, 1000):
  for i in range (2, a):
    if a%i == 0:
      result = False
      break
  print(result)
else:
  result = False
  print(result)
# Out:
# Enter a:5
# True

# %% [markdown]
# 7. Вводится целое число. Вывести число, обратное введенному по порядку составляющих его цифр. Например, введено 3425, надо вывести 5243.

# %%
a = input("Enter a:")
b = a[::-1]
print(b)
# Out:
# Enter a:12365
# 56321

# %% [markdown]
# 8. Посчитать четные и нечетные цифры числа
# Определить, сколько в числе четных цифр, а сколько нечетных. Число вводится с клавиатуры.

# %%
a = input("Enter a: ")
b = 0   #количество четных цифр
c = 0   #количество нечетных цифр
for i in a:
  if int(i)%2 == 0:
    b += 1
  else:
    c += 1
print("Number of even:", b) #количество четных цифр
print("Number of odd:", c) #количество нечетных цифр
# Out:
# Enter a: 224861539
# Number of even: 5
# Number of odd: 4

# %% [markdown]
# 9. Циклический сдвиг
#
# Выполнить циклический сдвиг в списке целых чисел на указанное число шагов. Сдвиг также должен быть кольцевым, то есть элемент, вышедший за пределы списка, должен появляться с другого его конца.
#
# Для решения этой задачи можно воспользоваться следующими методами списка:
#
# append() - добавляет элемент в конец списка,
# insert() - вставляет элемент по указанному индексу,
# pop() - извлекает элемент с конца списка или, если был передан индекс, по индексу.
#
# Если шаги представлены положительным числом, то сдвиг выполняется вправо, то есть надо извлечь последний элемент и добавить его в начало.
#
# Если шаги - отрицательное число, то будем выполнять сдвиг справа налево, то есть надо извлечь первый элемент и добавить его в конец.

# %%
list = [2, 4, 8, 12, 31, 5, 10, 13]
step = int(input("Enter step: "))
if step > 0:
   for i in range(step):
    list.insert(0, list.pop())
    print(list)
if step < 0:
   step = abs(step)
   for i in range(step):
    list.append(list.pop(0))
    print(list)
# Out:
# Enter step: -3
# [4, 8, 12, 31, 5, 10, 13, 2]
# [8, 12, 31, 5, 10, 13, 2, 4]
# [12, 31, 5, 10, 13, 2, 4, 8]

# %% [markdown]
# 10. Четыре соседние цифры в 1000-значном числе, которые имеют наибольшее произведение, равны 9 × 9 × 8 × 9 = 5832.
#
# mego_num = ''' 73167176531330624919225119674426574742355349194934 96983520312774506326239578318016984801869478851843 85861560789112949495459501737958331952853208805511 12540698747158523863050715693290963295227443043557 66896648950445244523161731856403098711121722383113 62229893423380308135336276614282806444486645238749 30358907296290491560440772390713810515859307960866 70172427121883998797908792274921901699720888093776 65727333001053367881220235421809751254540594752243 52584907711670556013604839586446706324415722155397 53697817977846174064955149290862569321978468622482 83972241375657056057490261407972968652414535100474 82166370484403199890008895243450658541227588666881 16427171479924442928230863465674813919123162824586 17866458359124566529476545682848912883142607690042 24219022671055626321111109370544217506941658960408 07198403850962455444362981230987879927244284909188 84580156166097919133875499200524063689912560717606 05886116467109405077541002256983155200055935729725 71636269561882670428252483600823257530420752963450
#
# Найдите наибольшее произведение тринадцати последовательных цифр в данном числе.

# %%
mego_num = "73167176531330624919225119674426574742355349194934 96983520312774506326239578318016984801869478851843 85861560789112949495459501737958331952853208805511 12540698747158523863050715693290963295227443043557 66896648950445244523161731856403098711121722383113 62229893423380308135336276614282806444486645238749 30358907296290491560440772390713810515859307960866 70172427121883998797908792274921901699720888093776 65727333001053367881220235421809751254540594752243 52584907711670556013604839586446706324415722155397 53697817977846174064955149290862569321978468622482 83972241375657056057490261407972968652414535100474 82166370484403199890008895243450658541227588666881 16427171479924442928230863465674813919123162824586 17866458359124566529476545682848912883142607690042 24219022671055626321111109370544217506941658960408 07198403850962455444362981230987879927244284909188 84580156166097919133875499200524063689912560717606 05886116467109405077541002256983155200055935729725 71636269561882670428252483600823257530420752963450"
mego_num = mego_num.replace(' ', '') # убираем пробелы из строки с 1000-значным числом
max = 0   
for i in range(len(mego_num) - 13):
    p = 1
    for j in range(i, i + 13):
      p *= int(mego_num[j])
    if p > max:
      max = p
print(max)
# Out:
# 23514624000

# %% [markdown]
# 11. Банкомат
#
# Стартовые требования.
#
# Есть класс Банкомат у него есть
# * Словарь с купюрами вида:
#     {номинал: количество, . . . }
# * Ф-ция выдачи, то есть мы вызываем эту ф-цию Банкомат.ф-ия(сумма) и нам выводит словарь с купюрами равными этой сумме.
# Например:
# Ввели 485
# Вывело {100:3, 50:3, 20:1, 10:1, 5:1}
#
# Продвинутые требования:
#
# Разработать алгоритм расчета оставшихся купюр так что бы в банкомате их оставалось оптимальное количество(примерно одинаковое количество номиналов)
#
# Максимальные требования:
#
# Интегрировать в наш банкомат счета пользователей.
# Авторизацию.
# Процент снимаемый банком.
# Разные валюты.
# И ± все возможности обычных банкоматов.
#
# Бонусом.
#
# Добавить интерфейс с помощью любых библиотек.
# Добавить инкассаторов, то есть добавить возможность наполнять и очищать банкомат.
# Выбор языка интерфейса.
# Деньги выдаются с задержкой в зависимости от суммы.
# Добавить блокировку аккаунта с возможностью разблокировки.
# Если пинкод введён задом наперед - тревожная кнопка, аккаунт блокируется.
# Возможность смены пароля.
# Если пинкод вводится дольше 10 сек - аккаунт блокируется.
# Любые нештяки которые придумаете.

# %%
from ast import keyword
atm = {
    "5": 14,
    "10": 18,
    "20": 32,
    "50": 9,
    "100": 5,
    "200": 2
}

maxSum = 5 * atm.get("5") + 10 * atm.get("10") + 20 * atm.get("20") + 50 * atm.get("50") + 100 * atm.get("100") + 200 * atm.get("200")
print("Максимальная сумма для снятия: ", maxSum)

while True:
  money = int(input("Введите сумму для снятия: ")) 
  if money > maxSum or money % 5 != 0:
    print("Ошибка! Недопустимая сумма для снятия, попробуйте еще раз.")
  else:
    break

atm2 = atm.copy() # словарь с выдаваемыми купюрами
if atm.get("200") >= money // 200 > 0:
  atm["200"] = atm.get("200") - money // 200
  atm2["200"] = money // 200
  money = money % 200
elif atm.get("200") <= money // 200 > 0:
  atm2["200"] = atm.get("200")
  money = money - atm.get("200") * 200
  atm["200"] = 0
else:
  atm2.pop("200") 
if atm.get("100") >= money // 100 > 0:
  atm["100"] = atm.get("100")- money // 100
  atm2["100"] = money // 100
elif atm.get("100") <= money // 100 > 0:
  atm2["100"] = atm.get("100")
  money = money - atm.get("100") * 100
  atm["100"] = 0 
else:
  atm2.pop("100")
if atm.get("50") >= money // 50 > 0:
  atm["50"] = atm.get("50")- money // 50
  atm2["50"] = money // 50
  money = money % 50
elif atm.get("50") <= money // 50 > 0:
  atm2["50"] = atm.get("50")
  money = money - atm.get("50") * 50
  atm["50"] = 0 
else:
  atm2.pop("50") 
if atm.get("20") >= money // 20 > 0:
  atm["20"] = atm.get("20")- money // 20
  atm2["20"] = money // 20
  money = money % 20
elif atm.get("20") <= money // 20 > 0:
  atm2["20"] = atm.get("20")
  money = money - atm.get("20") * 20
  atm["20"] = 0 
else:
  atm2.pop("20")
if atm.get("10") >= money // 10 > 0:
  atm["10"] = atm.get("10")- money // 10
  atm2["10"] = money // 10
  money = money % 10
elif atm.get("10") <= money // 10 > 0:
  atm2["10"] = atm.get("10")
  money = money - atm.get("10") * 10
  atm["10"] = 0 
else:
  atm2.pop("10")
if atm.get("5") >= money // 5 > 0:
  atm["5"] = atm.get("5")- money // 5
  atm2["5"] = money // 5
  money = money % 5
elif atm.get("5") <= money // 5 > 0:
  atm2["5"] = atm.get("5")
  money = money - atm.get("5") * 5
  atm["5"] = 0 
else:
  atm2.pop("5")

print()
print("Заберите деньги: ")
for key, value in atm2.items():
    print(key, ':', value, sep='')
print("Остаток купюр в банкомате: ", atm)
# Out:
# Максимальная сумма для снятия:  2240
# Введите сумму для снятия: 2240
#
# Заберите деньги:
# 5:14
# 10:18
# 20:32
# 50:9
# 100:5
# 200:2
# Остаток купюр в банкомате:  {'5': 0, '10': 0, '20': 0, '50': 0, '100': 0, '200': 0}
