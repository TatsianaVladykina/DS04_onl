# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls -a
# Out:
# ./  ../  .config/  drive/  sample_data/

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %mkdir GitHub

# %%
# %cd GitHub
# Out:
# /content/drive/MyDrive/GitHub

# %%
# %mkdir DSclass2023

# %%
# !git clone https://'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'@github.com/MarioLanzaCaro/DSclass2023
# Out:
# Cloning into 'DSclass2023'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 27 (delta 5), reused 10 (delta 0), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %%
# %cd DSclass2023
# Out:
# /content/drive/MyDrive/GitHub/DSclass2023

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %mkdir MalahavaNina

# %%
# %cd MalahavaNina
# Out:
# /content/drive/MyDrive/GitHub/DSclass2023/MalahavaNina

# %%
# !echo "test"  > test.txt

# %%
# %cd  ../
# Out:
# /content/drive/MyDrive/GitHub/DSclass2023

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   MalahavaNina/test.txt

# %%
# !git config --global user.email "koshka.koshak@gmail.com"

# %%
# !git config --global user.name "Malahava"

# %%
# !git commit -m 'Created personal folder оf Nina'
# Out:
# [main 031c16f] Created personal folder оf Nina
#  1 file changed, 1 insertion(+)
#  create mode 100644 MalahavaNina/test.txt

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git log
# Out:
# commit 031c16f9446d93eaf08e1755480f3a9f994436b6 (HEAD -> main)
# Author: Malahava <koshka.koshak@gmail.com>
# Date:   Thu Dec 15 13:55:16 2022 +0000
#
#     Created personal folder оf Nina
#
# commit bb68f76aba62685f928066d93e77cbbe4953dac1 (origin/main, origin/HEAD)
# Author: Pavel Koleda <pavdevlern@gmail.com>
# Date:   Thu Dec 15 07:21:08 2022 +0000
#
#     qewreqr folder deleted
#
# commit 421aa6cba88e989f61123ba7d6e8ad71d2969191
# Author: Pavel Koleda <pavdevlern@gmail.com>
# Date:   Thu Dec 15 07:16:36 2022 +0000
#
#     test file created
#
# commit 1fac36daed5a485da892c03b0ddc81978d824675
# Author: Pavel Koleda <pavdevlern@gmail.com>
# Date:   Wed Dec 14 16:18:19 2022 +0000
#
#     Created personal folder оf PavelKoleda4
#
# commit c7547f3947fb7d5207cd874874f7511e5983a599
# Author: Pavel Koleda <pavdevlern@gmail.com>
# Date:   Wed Dec 14 16:17:46 2022 +0000
#
#     Deleted test file from personal folder оf PavelKoleda2
#
# commit dfa0030ff1272f7c8358db5614fa49c9977222ac
# ...

# %%
# !git push origin
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/MarioLanzaCaro/DSclass2023 (fetch)
# origin	https://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@github.com/MarioLanzaCaro/DSclass2023 (push)
