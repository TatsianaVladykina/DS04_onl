# %% [markdown]
# Recommendation systems
#
# Работа с рекомендательными системами.
#
# Построение ассоциативных правил для датасета :
# Можно использовать например apriori, association_rules, fpgrowth из mlxtend.frequent_patterns (работают чуть быстрее).
# Написать выводы.
# https://www.kaggle.com/datasets/gorkhachatryan01/purchase-behaviour?select=dataset.csv

# %%
# !pip install mlxtend

# %%
import pandas as pd
import csv
import re

import matplotlib.pyplot as plt

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
from mpl_toolkits.mplot3d import Axes3D
import networkx as nx

# %% [markdown]
# import numpy as np
#
# import seaborn as sns

# %% [markdown]
# Набор данных записывает покупки отдельных товаров в строку. Сгруппируем эти покупки по корзинам товаров и удалим пустые значения.

# %%
dataset = []
with open('dataset.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        dataset.append(row)

# %%
basket = pd.Series(dataset)

# %%
basket = basket.apply(lambda x: [item for item in x if item != ''])
basket = basket.apply(lambda x: [item for item in x if item != ' '])

# %%
basket
# Out:
# 0       [ pork,  sandwich bags,  lunch meat,  all- pur...
# 1       [ shampoo,  hand soap,  waffles,  vegetables, ...
# 2       [ pork,  soap,  ice cream,  toilet paper,  din...
# 3       [ juice,  lunch meat,  soda,  toilet paper,  a...
# 4       [ pasta,  tortillas,  mixes,  hand soap,  toil...
#                               ...
# 1494    [ beef,  sandwich bags,  hand soap,  paper tow...
# 1495    [ dinner rolls,  lunch meat,  spaghetti sauce,...
# 1496    [ lunch meat,  eggs,  poultry,  vegetables,  t...
# 1497    [ ketchup,  milk,  poultry,  cheeses,  soap,  ...
# 1498    [ laundry detergent,  vegetables,  shampoo,  v...
# Length: 1499, dtype: object

# %% [markdown]
# С помощью TransactionEncoder мы закодируем транзакции в формат, подходящий для функции Apriori.

# %%
encoder = TransactionEncoder()
transactions = pd.DataFrame(encoder.fit(basket).transform(basket), columns=encoder.columns_)
display(transactions.head())
# Out:
#     all- purpose   aluminum foil   bagels   beef   butter   cereals   cheeses  \
# 0           True            True    False   True     True     False     False
# 1          False           False    False  False    False     False      True
# 2          False           False    False  False    False     False     False
# 3           True           False    False  False    False     False     False
# 4          False           False    False  False    False     False     False
#
#     coffee/tea   dinner rolls   dishwashing liquid/detergent  ...   shampoo  \
# 0        False           True                          False  ...      True
# 1        False          False                           True  ...      True
# 2        False           True                          False  ...     False
# 3        False          False                          False  ...     False
# 4        False          False                          False  ...     False
#
#     soap   soda   spaghetti sauce   sugar   toilet paper   tortillas  \
# 0  False   True             False   False          False       False
# 1  False  False             False   False          False       False
# 2   True  False              True   False           True       False
# 3  False   True             False   False           True       False
# 4  False  False             False   False           True        True
#
#     vegetables   waffles   yogurt
# 0         True     False    False
# 1         True      True    False
# 2        False     False    False
# 3        False     False    False
# 4         True     False    False
#
# [5 rows x 38 columns]

# %%
print(transactions.shape)
# Out:
# (1499, 38)

# %% [markdown]
# Алгоритм Apriori будет использоваться для генерации частых наборов элементов. Мы зададим минимальную поддержку в размере 6 из общего числа транзакций. Генерируются правила ассоциаций, и мы отфильтровываем значения Lift < 1,5 ,т.к. для значения lift >1,5 правил ассоциаций нет. Выбираем lift =1,4 , так более сильная связь в нашем наборе и их количество не минимально.

# %%
print(6/len(basket))
# Out:
# 0.004002668445630421

# %%
frequent_itemsets = apriori(transactions, min_support= 6/len(basket), use_colnames=True, max_len =3)
for i in range(11, 21):
    value = i / 10
    if 1.1 <= value <= 2.0:
        rules = association_rules(frequent_itemsets, metric="lift",  min_threshold = value)
        print(f"Lift = {value}, rules identified:{len(rules)} ")
# Out:
# Lift = 1.1, rules identified:9204
# Lift = 1.2, rules identified:3220
# Lift = 1.3, rules identified:850
# Lift = 1.4, rules identified:180
# Lift = 1.5, rules identified:22
# Lift = 1.6, rules identified:0
# Lift = 1.7, rules identified:0
# Lift = 1.8, rules identified:0
# Lift = 1.9, rules identified:0
# Lift = 2.0, rules identified:0

# %%
frequent_itemsets = apriori(transactions, min_support= 6/len(basket), use_colnames=True, max_len =3)
rules = association_rules(frequent_itemsets, metric="lift",  min_threshold = 1.4)
display(rules.head(20))
print("Rules identified: ", len(rules))
# Out:
#                            antecedents                         consequents  \
# 0               ( eggs,  all- purpose)                           ( bagels)
# 1             ( bagels,  all- purpose)                             ( eggs)
# 2                              ( eggs)            ( bagels,  all- purpose)
# 3                            ( bagels)              ( eggs,  all- purpose)
# 4               ( beef,  all- purpose)                           ( fruits)
# 5                            ( fruits)              ( beef,  all- purpose)
# 6              ( mixes,  all- purpose)                        ( hand soap)
# 7                         ( hand soap)             ( mixes,  all- purpose)
# 8                  ( hand soap,  soap)                     ( all- purpose)
# 9                      ( all- purpose)                 ( hand soap,  soap)
# 10  ( all- purpose,  individual meals)                     ( paper towels)
# 11                     ( paper towels)  ( all- purpose,  individual meals)
# 12           ( ketchup,  paper towels)                     ( all- purpose)
# 13                     ( all- purpose)           ( ketchup,  paper towels)
# 14     ( sandwich bags,  all- purpose)                             ( pork)
# 15                             ( pork)     ( sandwich bags,  all- purpose)
# 16          ( aluminum foil,  cereals)                            ( mixes)
# 17                            ( mixes)          ( aluminum foil,  cereals)
# 18                ( soda,  coffee/tea)                    ( aluminum foil)
# 19                    ( aluminum foil)                ( soda,  coffee/tea)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.071381            0.278185  0.029353    0.411215  1.478204
# 1             0.075384            0.268846  0.029353    0.389381  1.448341
# 2             0.268846            0.075384  0.029353    0.109181  1.448341
# 3             0.278185            0.071381  0.029353    0.105516  1.478204
# 4             0.068045            0.263509  0.026017    0.382353  1.451005
# 5             0.263509            0.068045  0.026017    0.098734  1.451005
# 6             0.070047            0.237492  0.024016    0.342857  1.443660
# 7             0.237492            0.070047  0.024016    0.101124  1.443660
# 8             0.056037            0.263509  0.020680    0.369048  1.400512
# 9             0.263509            0.056037  0.020680    0.078481  1.400512
# 10            0.070047            0.254837  0.025350    0.361905  1.420145
# 11            0.254837            0.070047  0.025350    0.099476  1.420145
# 12            0.054036            0.263509  0.020013    0.370370  1.405532
# 13            0.263509            0.054036  0.020013    0.075949  1.405532
# 14            0.064710            0.250167  0.022682    0.350515  1.401127
# 15            0.250167            0.064710  0.022682    0.090667  1.401127
# 16            0.069380            0.273516  0.028019    0.403846  1.476501
# 17            0.273516            0.069380  0.028019    0.102439  1.476501
# 18            0.066711            0.264176  0.024683    0.370000  1.400581
# 19            0.264176            0.066711  0.024683    0.093434  1.400581
#
#     leverage  conviction  zhangs_metric
# 0   0.009496    1.225939       0.348371
# 1   0.009086    1.197397       0.334793
# 2   0.009086    1.037940       0.423378
# 3   0.009496    1.038161       0.448181
# 4   0.008087    1.192414       0.333517
# 5   0.008087    1.034051       0.422032
# 6   0.007381    1.160339       0.330464
# 7   0.007381    1.034573       0.403033
# 8   0.005914    1.167269       0.302952
# 9   0.005914    1.024355       0.388295
# 10  0.007500    1.167793       0.318130
# 11  0.007500    1.032681       0.397022
# 12  0.005774    1.169721       0.305007
# 13  0.005774    1.023714       0.391757
# 14  0.006494    1.154505       0.306096
# 15  0.006494    1.028545       0.381803
# 16  0.009042    1.218619       0.346783
# 17  0.009042    1.036833       0.444226
# 18  0.007060    1.167974       0.306454
# 19  0.007060    1.029477       0.388694
# Rules identified:  180

# %%
frequent_itemsets
# Out:
#        support                             itemsets
# 0     0.263509                      ( all- purpose)
# 1     0.264176                     ( aluminum foil)
# 2     0.278185                            ( bagels)
# 3     0.262842                              ( beef)
# 4     0.261508                            ( butter)
# ...        ...                                  ...
# 9172  0.030020   ( waffles,  yogurt,  toilet paper)
# 9173  0.036024  ( vegetables,  waffles,  tortillas)
# 9174  0.045364   ( vegetables,  tortillas,  yogurt)
# 9175  0.014676      ( waffles,  tortillas,  yogurt)
# 9176  0.052035     ( waffles,  vegetables,  yogurt)
#
# [9177 rows x 2 columns]

# %%
rules
# Out:
#                   antecedents               consequents  antecedent support  \
# 0      ( eggs,  all- purpose)                 ( bagels)            0.071381
# 1    ( bagels,  all- purpose)                   ( eggs)            0.075384
# 2                     ( eggs)  ( bagels,  all- purpose)            0.268846
# 3                   ( bagels)    ( eggs,  all- purpose)            0.278185
# 4      ( beef,  all- purpose)                 ( fruits)            0.068045
# ..                        ...                       ...                 ...
# 175                   ( soda)          ( yogurt,  soap)            0.274183
# 176       ( waffles,  yogurt)           ( toilet paper)            0.078052
# 177  ( yogurt,  toilet paper)                ( waffles)            0.074049
# 178                ( waffles)  ( yogurt,  toilet paper)            0.278853
# 179           ( toilet paper)       ( waffles,  yogurt)            0.270180
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 0              0.278185  0.029353    0.411215  1.478204  0.009496    1.225939
# 1              0.268846  0.029353    0.389381  1.448341  0.009086    1.197397
# 2              0.075384  0.029353    0.109181  1.448341  0.009086    1.037940
# 3              0.071381  0.029353    0.105516  1.478204  0.009496    1.038161
# 4              0.263509  0.026017    0.382353  1.451005  0.008087    1.192414
# ..                  ...       ...         ...       ...       ...         ...
# 175            0.062041  0.024016    0.087591  1.411820  0.007005    1.028003
# 176            0.270180  0.030020    0.384615  1.423552  0.008932    1.185957
# 177            0.278853  0.030020    0.405405  1.453834  0.009371    1.212839
# 178            0.074049  0.030020    0.107656  1.453834  0.009371    1.037660
# 179            0.078052  0.030020    0.111111  1.423552  0.008932    1.037191
#
#      zhangs_metric
# 0         0.348371
# 1         0.334793
# 2         0.423378
# 3         0.448181
# 4         0.333517
# ..             ...
# 175       0.401884
# 176       0.322721
# 177       0.337128
# 178       0.432871
# 179       0.407678
#
# [180 rows x 10 columns]

# %%
def draw_network(rules, rules_to_show):
  # Ориентированный граф от NetworkX
  network = nx.DiGraph()
  
  # Перебор количества правил для отображения
  for i in range(rules_to_show):
    
    # Добавление узла правила
    network.add_nodes_from(["R"+str(i)])
    for antecedents in rules.iloc[i]['antecedents']: 
        # Добавление узла-предшественника и ссылки на правило
        network.add_nodes_from([antecedents])
        network.add_edge(antecedents, "R"+str(i),  weight = 2)
      
    for consequents in rules.iloc[i]['consequents']:
        # Добавление узла-последователя и ссылки на правило
        network.add_nodes_from([consequents])
        network.add_edge("R"+str(i), consequents,  weight = 2)

  color_map=[]  
  
  # Для каждого узла, если это правило, цвет черный, в противном случае - оранжевый.
  for node in network:
       if re.compile("^[R]\d+$").fullmatch(node) != None:
            color_map.append('black')
       else:
            color_map.append('orange')
  
  # Расположение узлов с помощью spring layout
  pos = nx.spring_layout(network, k=16, scale=1)
  # Построение сетевого графа
  nx.draw(network, pos, node_color = color_map, font_size=8)            
  
  # Сдвиг расположения текста вверх
  for p in pos:  
      pos[p][1] += 0.12

  nx.draw_networkx_labels(network, pos)
  plt.title("Network Graph for Association Rules")
  plt.show()

draw_network(rules, 15)
# Out:
# <>:24: DeprecationWarning: invalid escape sequence \d
# <>:24: DeprecationWarning: invalid escape sequence \d
# /var/folders/dj/qdtt8_0s0gzfptgftmg9zrch0000gp/T/ipykernel_5125/2633165278.py:24: DeprecationWarning: invalid escape sequence \d
#   if re.compile("^[R]\d+$").fullmatch(node) != None:

# %% [markdown]
# ### Применение алгоритма в бизнесе
# Допустим, владельцы магазина закупили слишком много beef и теперь беспокоятся, что товар пропадет, если его не удастся вовремя распродать. Что еще хуже, рентабельность продаж цельного молока настолько низка, что они не могут позволить себе промо-скидку, не потеряв при этом большую часть прибыли.

# %%
beef_rules = rules[rules['consequents'].astype(str).str.contains('beef')]
beef_rules = beef_rules.sort_values(by=['lift'],ascending = [False]).reset_index(drop = True)

display(beef_rules.head())
# Out:
#                antecedents             consequents  antecedent support  \
# 0                  ( pork)         ( mixes,  beef)            0.250167
# 1         ( sandwich bags)       ( beef,  cheeses)            0.250167
# 2  ( shampoo,  lunch meat)                 ( beef)            0.069380
# 3                ( fruits)  ( beef,  all- purpose)            0.263509
# 4                  ( pork)       ( beef,  ketchup)            0.250167
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.065377  0.025350    0.101333  1.549986  0.008995    1.040011
# 1            0.066711  0.025350    0.101333  1.518987  0.008661    1.038526
# 2            0.262842  0.026684    0.384615  1.463296  0.008449    1.197882
# 3            0.068045  0.026017    0.098734  1.451005  0.008087    1.034051
# 4            0.065377  0.023349    0.093333  1.427619  0.006994    1.030834
#
#    zhangs_metric
# 0       0.473216
# 1       0.455656
# 2       0.340215
# 3       0.422032
# 4       0.399466

# %%
print(beef_rules.sort_values(by=['lift'],ascending = [False]).reset_index(drop = True).head(10))
# Out:
#                antecedents             consequents  antecedent support  \
# 0                  ( pork)         ( mixes,  beef)            0.250167
# 1         ( sandwich bags)       ( beef,  cheeses)            0.250167
# 2  ( shampoo,  lunch meat)                 ( beef)            0.069380
# 3                ( fruits)  ( beef,  all- purpose)            0.263509
# 4                  ( pork)       ( beef,  ketchup)            0.250167
# 5               ( shampoo)    ( beef,  lunch meat)            0.248165
# 6            ( lunch meat)       ( beef,  shampoo)            0.276184
# 7      ( waffles,  fruits)                 ( beef)            0.074049
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.065377  0.025350    0.101333  1.549986  0.008995    1.040011
# 1            0.066711  0.025350    0.101333  1.518987  0.008661    1.038526
# 2            0.262842  0.026684    0.384615  1.463296  0.008449    1.197882
# 3            0.068045  0.026017    0.098734  1.451005  0.008087    1.034051
# 4            0.065377  0.023349    0.093333  1.427619  0.006994    1.030834
# 5            0.075384  0.026684    0.107527  1.426396  0.007977    1.036016
# 6            0.068712  0.026684    0.096618  1.406125  0.007707    1.030890
# 7            0.262842  0.027352    0.369369  1.405291  0.007888    1.168922
#
#    zhangs_metric
# 0       0.473216
# 1       0.455656
# 2       0.340215
# 3       0.422032
# 4       0.399466
# 5       0.397604
# 6       0.399032
# 7       0.311468

# %% [markdown]
# Например, мы можем установить промо-скидку на lunch meat, fruits, pork, sandwich bags,  shampoo. Некоторые ассоциации могут показаться контринтуитивными, но правила гласят, что эти продукты действительно стимулируют продажи цельного молока.

# %% [markdown]
# Применяя алгоритм Apriori и анализируя ассоциативные связи, предприятия могут вывести десятки стратегий, основанных на данных, для повышения доходов и прибыли. Правила ассоциаций имеют решающее значение для анализа покупательского поведения в процессе поиска данных. Некоторые из наиболее важных стратегий розничной торговли, такие как анализ клиентов, анализ рыночной корзины и кластеризация продуктов, способны дать ценные сведения в тандеме с анализом правил ассоциаций.

# %% [markdown]
# **Выводы**
#
# Преобразовали dataset в формат подходящий для функции Apriori. Для алгоритма Apriori зададим минимальную поддержку в размере 6 из общего числа транзакций. Взяли lift=1.4 для того чтобы были самые правила и их было не минимальное количество, как при 1.5.
# Затем построили ориентированный граф с нашими ассоциативными правилами.
# Рассмотрели алгоритм на связ с элементом beef и нашли зависимость между beef  lunch meat, fruits, pork, sandwich bags,  shampoo.
