# %% [markdown]
# Берем датасет из урока 14
#
# для столбцов Age и Balance определите:
#
# 1.размах вариации
#
# 2.среднее по выборке
#
# 3.медиану
#
# 4.стандартное отклонение
#
# Отфильтруйте данные - выберите для анализа записи о клиентах из Германии и расчитайте те же показатели.
#
# Сделайте выводы/предположения о содержимом датасета на основе полученных характеристик.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv('drive/MyDrive/ColabNotebooks/homework/Data/Churn_Modelling1.csv', index_col = 'RowNumber') #,chunksize=200

# %%
df.head(15)
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
# 6            15574012       Chu          645     Spain    Male   44       8
# 7            15592531  Bartlett          822    France    Male   50       7
# 8            15656148    Obinna          376   Germany  Female   29       4
# 9            15792365        He          501    France    Male   44       4
# 10           15592389        H?          684    France    Male   27       2
# 11           15767821    Bearce          528    France    Male   31       6
# ...

# %% [markdown]
# Age

# %%
R_age = df['Age'].max() - df['Age'].min()
R_age
# Out:
# 74

# %%
df['Age'].mean()
# Out:
# 38.9218

# %%
df['Age'].median()
# Out:
# 37.0

# %%
df['Age'].std()
# Out:
# 10.487806451704609

# %% [markdown]
# Среднее значение находится рядом с медианным значениенм, а стандартное отклонение невелико, получается что значение данных не сильно разбросаны относительно друг друга.

# %% [markdown]
# Balance

# %%
R_balance = df['Balance'].max() - df['Balance'].min()
R_balance
# Out:
# 250898.09

# %%
df['Balance'].mean()
# Out:
# 76485.889288

# %%
df['Balance'].median()
# Out:
# 97198.54000000001

# %%
df['Balance'].std()
# Out:
# 62397.405202385955

# %% [markdown]
# Большое стандартное отклонение показывает, что значения сильно разбросаны относительного среднего значения и представляют большую вариативность

# %% [markdown]
# Filter

# %%
df_germany = df[(df['Geography'] == 'Germany')]

# %%
df_germany
# Out:
#            CustomerId         Surname  CreditScore Geography  Gender  Age  \
# RowNumber
# 8            15656148          Obinna          376   Germany  Female   29
# 16           15643966         Goforth          616   Germany    Male   45
# 17           15737452           Romeo          653   Germany    Male   58
# 27           15736816           Young          756   Germany    Male   36
# 29           15728693      McWilliams          574   Germany  Female   43
# ...               ...             ...          ...       ...     ...  ...
# 9983         15768163         Griffin          655   Germany  Female   46
# 9985         15696175  Echezonachukwu          602   Germany    Male   35
# 9987         15581736        Bartlett          673   Germany    Male   47
# 9991         15798964      Nkemakonam          714   Germany    Male   33
# 9999         15682355       Sabbatini          772   Germany    Male   42
#
# ...

# %%
df_germany['Balance'].mean()
# Out:
# 119730.1161339179

# %%
df_germany['Balance'].median()
# Out:
# 119703.1

# %%
df_germany['Balance'].std()
# Out:
# 27022.006156656502

# %% [markdown]
# Практически равные значения медианы и среднего с небольшим отклонением.
