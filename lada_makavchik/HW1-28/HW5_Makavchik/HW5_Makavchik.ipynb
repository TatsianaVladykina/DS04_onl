# %% [markdown]
# **Задание 1**: Числа Фибоначчи
#
# Числа Фибоначчи – это ряд чисел, в котором каждое следующее число равно сумме двух предыдущих: 1, 1, 2, 3, 5, 8, 13, ... . Иногда ряд начинают с нуля: 0, 1, 1, 2, 3, 5, ... . В данном случае мы будем придерживаться первого варианта.
#
# Формула:
#
# F1 = 1
#
# F2 = 1
#
# Fn = Fn-1 + Fn-2
#
# Пример вычисления:
#
# F3 = F2 + F1 = 1 + 1 = 2
#
# F4 = F3 + F2 = 2 + 1 = 3
#
# F5 = F4 + F3 = 3 + 2 = 5
#
# F6 = F5 + F4 = 5 + 3 = 8

# %%
def fibonacci(n):
    if n <= 2:
        return 1
    return fibonacci(n - 1) + fibonacci(n - 2)

n = int(input('Введите нужный элемент последовательности: '))
print('Элемент', n, 'последовательности Фибоначчи равен:', fibonacci(n))
# Out:
# Введите нужный элемент последовательности: 10
# Этемент 10 последовательности Фибоначчи равен: 55

# %% [markdown]
# **Задание 2**: Банковский вклад. Пользователь делает вклад в размере a рублей сроком на years лет под 10% годовых (каждый год размер его вклада увеличивается на 10%. Эти деньги прибавляются к сумме вклада, и на них в следующем году тоже будут проценты).
#
# Написать программу bank, принимающая аргументы a и years, и возвращающую сумму, которая будет на счету пользователя.

# %%
a = int(input('Введите сумму вклада: '))
years = int(input('Введите количество лет: '))

def procent(summ):
    summ *= 1.1
    return summ

for i in range (years):
    a = procent(a)
print ("На счету пользователя будет: " , a)
# Out:
# Введите сумму вклада: 5000
# Введите количество лет: 5
# На счету пользователя будет:  8052.550000000004

# %% [markdown]
# **Задание 3** : Наибольший простой фактор
#
# Простые множители 13195: 5, 7, 13 и 29.
#
# Какой самый большой простой делитель числа 600851475143?

# %%
num = int(input("Введите число: "))
from datetime import datetime
start = datetime.now()
def prostoe(num):
  r =  round(num ** 0.5)
  for i in range (r, 1, -1):
    if num % i == 0:
        for j in range(2, i):
            if i % j == 0:
                break
            elif i % j != 0 and j != (i - 1):
                continue
            elif i % j != 0 and j == (i - 1):
                return i
print('Самый большой простой делитель числа', num, 'равняется:' , prostoe(num))
print('VREMY:', datetime.now() - start)
# Out:
# Введите число: 600851475143
# Самый большой простой делитель числа 600851475143 равняется: 6857
# VREMY: 0:00:00.102868

# %% [markdown]
# **Задание 4**: Наименьшее кратное
#
# 2520 - это наименьшее число, которое можно разделить на каждое из чисел от 1 до 10 без остатка.
#
# Какое наименьшее положительное число делится без остатка на все числа от 1 до 20?

# %%
# нок = a * b / нод

def nok(a, b):
    return a * b // nod(a,b)

def nod(a,b):
    while a != b:
        if a > b:
            a -= b
        else:
            b -= a
    return a

num = 1
for i in range(2, 21):
    num = nok(num, i)
print ('Наименьшее число, которое делится на все числа от 1 до 20 без остатка: ', num)
# Out:
# Наименьшее число, которое делится на все числа от 1 до 20 без остатка:  232792560

# %% [markdown]
# **Задание 5**: Сумма квадратов разницы
#
# Сумма квадратов первых десяти натуральных чисел равна,
#
# 1 ** 2 + 2 ** 2 + ... + 10 ** 2 = 385
#
# Квадрат суммы первых десяти натуральных чисел равен,
#
# (1 + 2 + ... + 10) ** 2 = 55 ** 2 = 3025
#
# Следовательно, разница между суммой квадратов первых десяти натуральных чисел и квадратом суммы равна .
#
# Найдите разницу между суммой квадратов первых ста натуральных чисел и квадратом суммы.

# %%
def sum_kv(a):
    if a == 1:
        return a**2
    return a **2 + sum_kv(a - 1)

def kv_sum(a):
    if a == 1:
        return a
    return a + kv_sum(a - 1)

sk = sum_kv(100)
print('Сумма квадратов: ', sk)
ks = kv_sum(100) ** 2
print('Квадрат суммы: ', ks)
raz = sk - ks
print('Разница между суммой квадратов и квадратом суммы: ', raz)
# Out:
# Сумма квадратов:  338350
# Квадрат суммы:  25502500
# Разница между суммой квадратов и квадратом суммы:  -25164150

# %% [markdown]
# **Задание 6**:
#
# Перечислив первые шесть простых чисел: 2, 3, 5, 7, 11 и 13, мы видим, что 6-е простое число равно 13.
#
# Какое 10 001-е простое число?

# %%
from datetime import datetime

def prostoe(n):
  r =  round(n ** 0.5) + 1
  for i in range (2, r):
    if n % i == 0:
      return False
    elif n % i != 0 and i != (r - 1):
      continue
    elif n % i != 0 and i == (r - 1):
      return True

n=3
start = datetime.now()
k = 1
while True:
  if k==10001:
    last_prostoe = n - 2
    break
  if prostoe(n) is True:
    k += 1

  n += 2

print('VREMY:', datetime.now() - start)
print('10001-е простое число:', last_prostoe)
# Out:
# VREMY: 0:00:00.631242
# 10001-е простое число: 104743

# %% [markdown]
# **Задание 7**:
#
# Task_30 **
# Самая длинная последовательность Коллатца
#
# Следующая итерационная последовательность определена для набора натуральных чисел:
#
# Если n чётное n = n/2
#
# Если n нечётное n = n*3 + 1
#
# Используя приведенное выше правило и начиная с 13, мы генерируем следующую последовательность:
#
# 13 -> 40 -> 20 -> 10 -> 5 -> 16 -> 8 -> 4 -> 2 -> 1
#
# Видно, что эта последовательность (начиная с 13 и заканчивая 1) содержит 10 терминов. Хотя это еще не доказано (задача Коллатца), считается, что все стартовые номера заканчиваются на 1.
#
# Какое начальное число, меньшее миллиона, дает самую длинную цепочку?
#
# ПРИМЕЧАНИЕ: Как только цепочка начинается, термины могут превышать один миллион.
#
# Дополнительное условие:
# Максимальная скорсть работы программы среди всех слушателей.

# %%
from datetime import datetime
start = datetime.now()

limit  = 1_000_000
memo = [0] * limit
memo[1] = 1
for i in range(3, limit + 1):
  j = i
  k = 0
  while j != 1:
    if  j < limit and memo[j - 1] != 0:
      k += memo[j - 1]
      break
    else:
      if j % 2 == 0:
        j = j // 2
      else:
        j = j * 3 + 1
      k += 1
  memo[i - 1] = k

print('VREMY:', datetime.now() - start)
print('Максимальное количество шагов:', max(memo))
print('Элемент с максимальным количеством шагов:', memo.index(max(memo)) + 1)
# Out:
# VREMY: 0:00:02.502575
# Максимальное количество шагов: 524
# Элемент с максимальным количеством шагов: 837799
